# %% [markdown]
# ---
# jupyter:
#   jupytext:
#     text_representation:
#       extension: .qmd
#       format_name: quarto
#       format_version: '1.0'
#       jupytext_version: 1.18.1
#   kernelspec:
#     display_name: Python 3
#     language: python
#     name: python3
# ---
#
# ## Test

# %%
import pandas as pd

pd.DataFrame({"a": 1, "b": 2})

# %%
2 + 2

# %%
3 + 3
